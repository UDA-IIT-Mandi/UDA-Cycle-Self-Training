# %% [markdown]
# # Cycle Self Training Implementation on DCASE TAU 2020 Dataset

# %%
import random
import time
import warnings
import sys
import argparse
import shutil
import os.path as osp
import os
import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
from torch.optim import SGD
from torch.optim.lr_scheduler import LambdaLR
from torch.utils.data import DataLoader
import torchvision.transforms as T
import torch.nn.functional as F

import librosa
from hear21passt.base import get_basic_model
import datetime
import matplotlib.pyplot as plt
from collections import defaultdict
from typing import Tuple, Optional, List, Dict
from types import SimpleNamespace

# %%
sys.path.append(os.path.dirname(os.getcwd()))
import common.audio.datasets as datasets
from common.audio.transforms import TransformFixMatch
from common.audio.transforms import WeakAugment
from common.audio.transforms import StrongAugment
from common.utils.data import ForeverDataIterator
from common.utils.metric import accuracy, ConfusionMatrix
from common.utils.meter import AverageMeter, ProgressMeter
from common.utils.logger import CompleteLogger
from common.utils.analysis import collect_feature, tsne, a_distance
from common.tools.randaugment import rand_augment_transform, GaussianBlur
from common.tools.sam import SAM

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using Device:", device)
# Out:
# Using Device: cuda

# %%
args = SimpleNamespace(
    root = './data/dcase',
    data = 'DCASE',          
    source = 'source',      
    target = 'target',
    temperature = 2.0,
    alpha = 1.9,
    trade_off = 0.08,
    trade_off1 = 0.5,
    trade_off3 = 0.5,
    threshold = 0.97,
    rho = 0.5,
    batch_size = 3,
    lr = 0.0005,
    lr_gamma = 0.001,
    lr_decay = 0.75,
    momentum = 0.9,
    weight_decay = 1e-3,
    workers = 8,
    epochs = 100,
    early = 80,
    iters_per_epoch = 1000,
    val_interval = 5,
    print_freq = 100,        
    seed = None,             
    per_class_eval = False,  
    log = 'logs/dcase',             
    phase = 'train', 
    sample_rate = 32000,
    clip_length = 10,
    num_cls = 10,
    device = device,
    
)
print("Arguments set for CST experiment (DCASE TAU 2020):")
for k, v in args.__dict__.items():
    print(f"{k} = {v}")
# Out:
# Arguments set for CST experiment (DCASE TAU 2020):
# root = ./data/dcase
# data = DCASE
# source = source
# target = target
# temperature = 2.0
# alpha = 1.9
# trade_off = 0.08
# trade_off1 = 0.5
# trade_off3 = 0.5
# threshold = 0.97
# rho = 0.5
# batch_size = 3
# lr = 0.0005
# lr_gamma = 0.001
# lr_decay = 0.75
# momentum = 0.9
# weight_decay = 0.001
# workers = 8
# epochs = 100
# early = 80
# iters_per_epoch = 1000
# val_interval = 5
# print_freq = 100
# seed = None
# per_class_eval = False
# log = logs/dcase
# phase = train
# sample_rate = 32000
# clip_length = 10
# num_cls = 10
# device = cuda

# %%
def entropy(predictions: torch.Tensor, reduction='none') -> torch.Tensor:
    epsilon = 1e-5
    H = -predictions * torch.log(predictions + epsilon)
    H = H.sum(dim=1)
    if reduction == 'mean':
        return H.mean()
    else:
        return H

class TsallisEntropy(nn.Module):
    def __init__(self, temperature: float, alpha: float):
        super(TsallisEntropy, self).__init__()
        self.temperature = temperature
        self.alpha = alpha

    def forward(self, logits: torch.Tensor) -> torch.Tensor:
        N, C = logits.shape
        pred = F.softmax(logits / self.temperature, dim=1) 
        entropy_weight = entropy(pred).detach()
        entropy_weight = 1 + torch.exp(-entropy_weight)
        entropy_weight = (N * entropy_weight / torch.sum(entropy_weight)).unsqueeze(dim=1)  
        sum_dim = torch.sum(pred * entropy_weight, dim = 0).unsqueeze(dim=0)
        return 1 / (self.alpha - 1) * torch.sum((1 / torch.mean(sum_dim) - torch.sum(pred ** self.alpha / sum_dim * entropy_weight, dim = -1)))

# %%
class AudioClassifier (nn.Module):
    def __init__(self, backbone, num_classes, bottleneck_dim=256, finetune=True):
        super(AudioClassifier, self).__init__()
        self.backbone = backbone  
        self.bottleneck = nn.Sequential(
            nn.Linear(768, bottleneck_dim),  
            nn.BatchNorm1d(bottleneck_dim),
            nn.ReLU()
        )
        self.head = nn.Linear(bottleneck_dim, num_classes)
        self.finetune = finetune

        if not finetune:
            for param in self.backbone.parameters():
                param.requires_grad = False

    def forward(self, x):
        features = self.backbone(x)
        embeddings = self.bottleneck(features)
        outputs = self.head(embeddings)
        return outputs, embeddings

    def get_parameters(self, base_lr=1.0) -> List[Dict]:
        """A parameter list which decides optimization hyper-parameters,
            such as the relative learning rate of each layer
        """
        params = [
            {"params": self.backbone.parameters(), "lr": 0.1 * base_lr if self.finetune else 1.0 * base_lr},
            {"params": self.bottleneck.parameters(), "lr": 1.0 * base_lr},
            {"params": self.head.parameters(), "lr": 1.0 * base_lr},
        ]

        return params

# %%
# Data loading code
train_transform = WeakAugment()
unlabeled_transform = TransformFixMatch()
val_transform = WeakAugment()  

dataset = datasets.__dict__[args.data]

base_source_dataset = dataset(root=args.root, task=args.source, split='train', transform=None)
base_target_dataset = dataset(root=args.root, task=args.target, split='train', transform=None)

train_size_s = int(0.9 * len(base_source_dataset))
val_size_s = len(base_source_dataset) - train_size_s
train_indices_s, val_indices_s = torch.utils.data.random_split(range(len(base_source_dataset)), [train_size_s, val_size_s])

train_size_t = int(0.9 * len(base_target_dataset))
val_size_t = len(base_target_dataset) - train_size_t
train_indices_t, val_indices_t = torch.utils.data.random_split(range(len(base_target_dataset)), [train_size_t, val_size_t])

train_source_dataset = torch.utils.data.Subset(
    dataset(root=args.root, task=args.source, split='train', transform=train_transform),
    train_indices_s.indices
)

val_source_dataset = torch.utils.data.Subset(
    dataset(root=args.root, task=args.source, split='train', transform=val_transform),
    val_indices_s.indices
)

train_target_dataset = torch.utils.data.Subset(
    dataset(root=args.root, task=args.target, split='train', transform=unlabeled_transform),
    train_indices_t.indices
)

val_target_dataset = torch.utils.data.Subset(
    dataset(root=args.root, task=args.target, split='train', transform=val_transform),
    val_indices_t.indices
)

train_source_loader = DataLoader(train_source_dataset, batch_size=args.batch_size, shuffle=True, num_workers=args.workers, drop_last=True)
train_target_loader = DataLoader(train_target_dataset, batch_size=args.batch_size, shuffle=True, num_workers=args.workers, drop_last=True)
val_source_loader = DataLoader(val_source_dataset, batch_size=args.batch_size, shuffle=False, num_workers=args.workers)
val_target_loader = DataLoader(val_target_dataset, batch_size=args.batch_size, shuffle=False, num_workers=args.workers)

test_source_dataset = dataset(root=args.root, task=args.source, split='test', transform=val_transform)
test_source_loader = DataLoader(test_source_dataset, batch_size=args.batch_size, shuffle=False, num_workers=args.workers)

test_target_dataset = dataset(root=args.root, task=args.target, split='test', transform=val_transform)
test_target_loader = DataLoader(test_target_dataset, batch_size=args.batch_size, shuffle=False, num_workers=args.workers)

train_source_iter = ForeverDataIterator(train_source_loader)
train_target_iter = ForeverDataIterator(train_target_loader)

print(f"Train source samples: {len(train_source_dataset)}")
print(f"Train target samples: {len(train_target_dataset)}")
print(f"Val source samples: {len(val_source_dataset)}")
print(f"Val target samples: {len(val_target_dataset)}")
print(f"Test source samples: {len(test_source_dataset)}")
print(f"Test target samples: {len(test_target_dataset)}")
# Out:
# Train source samples: 9193
# Train target samples: 3372
# Val source samples: 1022
# Val target samples: 375
# Test source samples: 330
# Test target samples: 2638

# %%
# create model
print("=> using pre-trained model PaSST")
backbone = get_basic_model(mode="embed_only")
backbone.eval() 
classifier = AudioClassifier(backbone, num_classes=10).to(device)
# Out:
# => using pre-trained model PaSST
# Warning: FMAX is None setting to 15000
#
#
#  Loading PASST TRAINED ON AUDISET
#
#
# PaSST(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(1, 768, kernel_size=(16, 16), stride=(10, 10))
#     (norm): Identity()
#   )
#   (pos_drop): Dropout(p=0.0, inplace=False)
#   (blocks): Sequential(
#     (0): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (1): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (2): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (3): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (4): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (5): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (6): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (7): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (8): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (9): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (10): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#     (11): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (drop_path): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU(approximate='none')
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   (pre_logits): Identity()
#   (head): Sequential(
#     (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (1): Linear(in_features=768, out_features=527, bias=True)
#   )
#   (head_dist): Linear(in_features=768, out_features=527, bias=True)
# )

# %%
def main(args: argparse.Namespace):
    logger = CompleteLogger(args.log, args.phase)
    print(args)

    if args.seed is not None:
        random.seed(args.seed)
        torch.manual_seed(args.seed)
        cudnn.deterministic = True
        warnings.warn('You have chosen to seed training. '
                      'This will turn on the CUDNN deterministic setting, '
                      'which can slow down your training considerably! '
                      'You may see unexpected behavior when restarting '
                      'from checkpoints.')

    cudnn.benchmark = True
    
    # define optimizer and lr scheduler
    base_optimizer = SGD
    optimizer = SAM(classifier.get_parameters(), base_optimizer, lr = args.lr,
                                momentum=args.momentum,
                                weight_decay=args.weight_decay, adaptive = True, rho = args.rho)
    lr_scheduler = LambdaLR(optimizer, lambda x:  args.lr * (1. + args.lr_gamma * float(x)) ** (-args.lr_decay))

    # define loss function
    ts_loss = TsallisEntropy(temperature=args.temperature, alpha = args.alpha)

    # resume from the best checkpoint
    if args.phase != 'train':
        checkpoint = torch.load(logger.get_checkpoint_path('best'), map_location='cpu')
        classifier.load_state_dict(checkpoint)

    # analysis the model
    if args.phase == 'analysis':
        # extract features from both domains
        feature_extractor = nn.Sequential(classifier.backbone, classifier.bottleneck).to(device)
        source_feature = collect_feature(train_source_loader, feature_extractor, device)
        target_feature = collect_feature(train_target_loader, feature_extractor, device)
        # plot t-SNE
        tSNE_filename = osp.join(logger.visualize_directory, 'TSNE.png')
        tsne.visualize(source_feature, target_feature, tSNE_filename)
        print("Saving t-SNE to", tSNE_filename)
        # calculate A-distance, which is a measure for distribution discrepancy
        A_distance = a_distance.calculate(source_feature, target_feature, device)
        print("A-distance =", A_distance)
        return

    if args.phase == 'test':
        acc_s, _ = validate(test_source_loader, classifier, args)
        print(acc_s)

        acc_t, _ = validate(test_target_loader, classifier, args)
        print(acc_t)
        return

    # start training
    best_acc_s = 0.
    best_acc_t = 0.
    for epoch in range(min(args.epochs, args.early)):
        print("lr:", lr_scheduler.get_last_lr()[0])
        # train for one epoch
        train(train_source_iter, train_target_iter, classifier, ts_loss, optimizer,
              lr_scheduler, epoch, args)

        # evaluate on validation set
        if (epoch + 1) % args.val_interval == 0 or epoch == args.epochs - 1:
            acc_s, device_results_s = validate(val_source_loader, classifier, args)
            acc_t, device_results_t = validate(val_target_loader, classifier, args)
            
    
            # remember best acc@1 and save checkpoint
            torch.save(classifier.state_dict(), logger.get_checkpoint_path('latest'))
            if acc_s > best_acc_s:
                shutil.copy(logger.get_checkpoint_path('latest'), logger.get_checkpoint_path('best'))
            best_acc_s = max(acc_s, best_acc_s)
    
            if acc_t > best_acc_t:
                shutil.copy(logger.get_checkpoint_path('latest'), logger.get_checkpoint_path('best'))
            best_acc_t = max(acc_t, best_acc_t)

            print("Best Source Accuracy = {:3.1f}".format(best_acc_s))
            print("Best Target Accuracy = {:3.1f}".format(best_acc_t))

        else:
            torch.save(classifier.state_dict(), logger.get_checkpoint_path('latest'))

    

    # evaluate on test set
    classifier.load_state_dict(torch.load(logger.get_checkpoint_path('best')))
    acc_s, _ = validate(test_source_loader, classifier, args)
    print("Test Source Accuracy = {:3.1f}".format(acc_s))

    acc_t, _ = validate(test_target_loader, classifier, args)
    print("Test Target Accuracy = {:3.1f}".format(acc_t))

    logger.close()

# %%
def train(train_source_iter: ForeverDataIterator, train_target_iter: ForeverDataIterator,
          model: AudioClassifier, ts: TsallisEntropy, optimizer: SGD,
          lr_scheduler: LambdaLR, epoch: int, args: argparse.Namespace):
    batch_time = AverageMeter('Time', ':3.1f')
    data_time = AverageMeter('Data', ':3.1f')
    losses = AverageMeter('Loss', ':3.2f')
    trans_losses = AverageMeter('Trans Loss', ':3.2f')
    rev_losses = AverageMeter('CST Loss', ':3.2f')
    fix_losses = AverageMeter('Fix Loss', ':3.2f')
    cls_accs = AverageMeter('Cls Acc', ':3.1f')

    progress = ProgressMeter(
        args.iters_per_epoch,
        [batch_time, data_time, losses, trans_losses, rev_losses, fix_losses, cls_accs],
        prefix="Epoch: [{}]".format(epoch))

    # switch to train mode
    model.train()

    end = time.time()
    for i in range(args.iters_per_epoch):
        x_s, labels_s, _, _ = next(train_source_iter)
        (x_t, x_t_u), _, _, _ = next(train_target_iter)

        x_s = x_s.to(device)
        x_t = x_t.to(device)
        x_t_u = x_t_u.to(device)
        labels_s = labels_s.to(device)

        # measure data loading time
        data_time.update(time.time() - end)

        # compute output
        x = torch.cat((x_s, x_t), dim=0)
        y, f = model(x)
        y_t_u, _ = model(x_t_u)

        f_s, f_t = f.chunk(2, dim=0)
        y_s, y_t = y.chunk(2, dim=0)

        # generate target pseudo-labels
        max_prob, pred_u = torch.max(F.softmax(y_t), dim=-1)
        Lu = (F.cross_entropy(y_t_u, pred_u,
                              reduction='none') * max_prob.ge(args.threshold).float().detach()).mean()

        # compute cst
        target_data_train_r = f_t
        target_data_train_r = target_data_train_r / (torch.norm(target_data_train_r, dim = -1).reshape(target_data_train_r.shape[0], 1))
        target_data_test_r = f_s
        target_data_test_r = target_data_test_r / (torch.norm(target_data_test_r, dim = -1).reshape(target_data_test_r.shape[0], 1))
        target_gram_r = torch.clamp(target_data_train_r.mm(target_data_train_r.transpose(dim0 = 1, dim1 = 0)),-0.99999999,0.99999999)
        target_kernel_r = target_gram_r
        test_gram_r = torch.clamp(target_data_test_r.mm(target_data_train_r.transpose(dim0 = 1, dim1 = 0)),-0.99999999,0.99999999)
        test_kernel_r = test_gram_r
        target_train_label_r = torch.nn.functional.one_hot(pred_u, args.num_cls) - 1 / float(args.num_cls) 
        target_test_pred_r = test_kernel_r.mm(torch.inverse(target_kernel_r + 0.001 * torch.eye(args.batch_size).cuda())).mm(target_train_label_r)
        reverse_loss = nn.MSELoss()(target_test_pred_r, torch.nn.functional.one_hot(labels_s, args.num_cls) - 1 / float(args.num_cls)) 

        cls_loss = F.cross_entropy(y_s, labels_s)
        transfer_loss = ts(y_t)

        if Lu != 0:
            loss = cls_loss + transfer_loss * args.trade_off + reverse_loss * args.trade_off1 + Lu * args.trade_off3
        else: 
            loss = cls_loss + transfer_loss * args.trade_off + reverse_loss * args.trade_off1

        cls_acc = accuracy(y_s, labels_s)[0]

        losses.update(loss.item(), x_s.size(0))
        cls_accs.update(cls_acc.item(), x_s.size(0))
        trans_losses.update(transfer_loss.item(), x_s.size(0))
        rev_losses.update(reverse_loss.item(), x_s.size(0))
        fix_losses.update(Lu.item(), x_s.size(0))

        # compute gradient and do the first SGD step
        loss.backward()
        optimizer.first_step(zero_grad=True)
        lr_scheduler.step()

        # compute gradient and do the second SGD step
        y, f = model(x)
        y_t_u, _ = model(x_t_u)

        f_s, f_t = f.chunk(2, dim=0)
        y_s, y_t = y.chunk(2, dim=0)

        # generate target pseudo-labels
        max_prob, pred_u = torch.max(F.softmax(y_t), dim=-1)
        Lu = (F.cross_entropy(y_t_u, pred_u,
                              reduction='none') * max_prob.ge(args.threshold).float().detach()).mean()

        # compute cst
        target_data_train_r = f_t
        target_data_train_r = target_data_train_r / (torch.norm(target_data_train_r, dim = -1).reshape(target_data_train_r.shape[0], 1))
        target_data_test_r = f_s
        target_data_test_r = target_data_test_r / (torch.norm(target_data_test_r, dim = -1).reshape(target_data_test_r.shape[0], 1))
        target_gram_r = torch.clamp(target_data_train_r.mm(target_data_train_r.transpose(dim0 = 1, dim1 = 0)),-0.99999999,0.99999999)
        target_kernel_r = target_gram_r
        test_gram_r = torch.clamp(target_data_test_r.mm(target_data_train_r.transpose(dim0 = 1, dim1 = 0)),-0.99999999,0.99999999)
        test_kernel_r = test_gram_r
        target_train_label_r = torch.nn.functional.one_hot(pred_u, args.num_cls) - 1 / float(args.num_cls) 
        target_test_pred_r = test_kernel_r.mm(torch.inverse(target_kernel_r + 0.001 * torch.eye(args.batch_size).cuda())).mm(target_train_label_r)
        reverse_loss = nn.MSELoss()(target_test_pred_r, torch.nn.functional.one_hot(labels_s, args.num_cls) - 1 / float(args.num_cls)) 

        cls_loss = F.cross_entropy(y_s, labels_s)
        transfer_loss = ts(y_t)

        if Lu != 0:
            loss1 = cls_loss + transfer_loss * args.trade_off + reverse_loss * args.trade_off1 + Lu * args.trade_off3
        else: 
            loss1 = cls_loss + transfer_loss * args.trade_off + reverse_loss * args.trade_off1

        loss1.backward()
        optimizer.second_step(zero_grad=True)

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        if i % args.print_freq == 0:
            progress.display(i)

# %%
def evaluate_by_device(model, test_target_loader, device):
    model.eval()
    device_results = defaultdict(lambda: {'correct': 0, 'total': 0})
    
    with torch.no_grad():
        for audio, labels, domains, devices in test_target_loader:
            audio = audio.to(device)
            labels = labels.to(device)
            
            outputs = model(audio)
            _, predicted = torch.max(outputs.data, 1)
            
            for i, dev in enumerate(devices):
                device_results[dev]['total'] += 1
                if predicted[i] == labels[i]:
                    device_results[dev]['correct'] += 1
    
    results = {}
    for dev in device_results:
        correct = device_results[dev]['correct']
        total = device_results[dev]['total']
        accuracy = 100.0 * correct / total
        results[dev] = {'accuracy': accuracy, 'total': total}
        print(f'Device {dev}: Accuracy = {accuracy:.2f}% ({correct}/{total})')
    
    return results

# %%
def validate(val_loader: DataLoader, model: AudioClassifier, args: argparse.Namespace) -> float:
    batch_time = AverageMeter('Time', ':6.3f')
    losses = AverageMeter('Loss', ':.4e')
    top1 = AverageMeter('Acc@1', ':6.2f')
    top5 = AverageMeter('Acc@5', ':6.2f')
    progress = ProgressMeter(
        len(val_loader),
        [batch_time, losses, top1, top5],
        prefix='Test: ')

    # switch to evaluate mode
    model.eval()
    device_results = defaultdict(lambda: {'correct': 0, 'total': 0})
    if args.per_class_eval:
        classes = val_loader.dataset.classes
        confmat = ConfusionMatrix(len(classes))
    else:
        confmat = None

    with torch.no_grad():
        end = time.time()
        for i, (audio, target, _, devices) in enumerate(val_loader):
            audio = audio.to(args.device)
            target = target.to(args.device)

            # compute output
            output, _ = model(audio)
            loss = F.cross_entropy(output, target)

            # measure accuracy and record loss
            acc1, acc5 = accuracy(output, target, topk=(1, 5))
            if confmat:
                confmat.update(target, output.argmax(1))
            losses.update(loss.item(), audio.size(0))
            top1.update(acc1.item(), audio.size(0))
            top5.update(acc5.item(), audio.size(0))

            # Update device-specific results
            pred = output.argmax(dim=1)
            for j, dev in enumerate(devices):
                device_results[dev]['total'] += 1
                if pred[j] == target[j]:
                    device_results[dev]['correct'] += 1

            # measure elapsed time
            batch_time.update(time.time() - end)
            end = time.time()

            if i % args.print_freq == 0:
                progress.display(i)

        print(' * Acc@1 {top1.avg:.3f} Acc@5 {top5.avg:.3f}'
              .format(top1=top1, top5=top5))
        if confmat:
            print(confmat.format(classes))

        print("\nDevice-specific results:")
        for dev in device_results:
            correct = device_results[dev]['correct']
            total = device_results[dev]['total']
            acc = 100.0 * correct / total
            print(f'Device {dev}: {acc:.2f}% ({correct}/{total})')
            
    return top1.avg, device_results

# %%
main(args)
# Out:
# namespace(root='./data/dcase', data='DCASE', source='source', target='target', temperature=2.0, alpha=1.9, trade_off=0.08, trade_off1=0.5, trade_off3=0.5, threshold=0.97, rho=0.5, batch_size=3, lr=0.0005, lr_gamma=0.001, lr_decay=0.75, momentum=0.9, weight_decay=0.001, workers=8, epochs=100, early=80, iters_per_epoch=1000, val_interval=5, print_freq=100, seed=None, per_class_eval=False, log='logs/dcase', phase='train', sample_rate=32000, clip_length=10, num_cls=10, device=device(type='cuda'))
# lr: 5e-05
# /home/teaching/miniconda3/lib/python3.12/site-packages/torch/functional.py:730: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at /pytorch/aten/src/ATen/native/SpectralOps.cpp:875.)
#   return _VF.stft(  # type: ignore[attr-defined]
# /home/teaching/miniconda3/lib/python3.12/site-packages/hear21passt/models/preprocess.py:71: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# x torch.Size([6, 1, 128, 1000])
# /home/teaching/miniconda3/lib/python3.12/site-packages/hear21passt/models/passt.py:304: UserWarning: Input image size (128*1000) doesn't match model (128*998).
#   warnings.warn(f"Input image size ({H}*{W}) doesn't match model ({self.img_size[0]}*{self.img_size[1]}).")
# self.norm(x) torch.Size([6, 768, 12, 99])
#  patch_embed :  torch.Size([6, 768, 12, 99])
#  self.time_new_pos_embed.shape torch.Size([1, 768, 1, 99])
#  self.freq_new_pos_embed.shape torch.Size([1, 768, 12, 1])
# X flattened torch.Size([6, 1188, 768])
#  self.new_pos_embed.shape torch.Size([1, 2, 768])
#  self.cls_tokens.shape torch.Size([6, 1, 768])
#  self.dist_token.shape torch.Size([6, 1, 768])
#  final sequence x torch.Size([6, 1190, 768])
#  after 12 atten blocks x torch.Size([6, 1190, 768])
# forward_features torch.Size([6, 768])
# head torch.Size([6, 527])
# /tmp/ipykernel_1311482/1974896290.py:42: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   max_prob, pred_u = torch.max(F.softmax(y_t), dim=-1)
# /home/teaching/miniconda3/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:182: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# /tmp/ipykernel_1311482/1974896290.py:88: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   max_prob, pred_u = torch.max(F.softmax(y_t), dim=-1)
# Epoch: [0][   0/1000]	Time 1.8 (1.8)	Data 0.0 (0.0)	Loss 3.77 (3.77)	Trans Loss 9.70 (9.70)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 0.0 (0.0)

# %%
"Display Training Log"
with open('./logs/dcase/train-2025-06-28-14_10_58.txt', 'r') as f:
    for line in f:
        print(line, end='')
# Out:
# namespace(root='./data/dcase', data='DCASE', source='source', target='target', temperature=2.0, alpha=1.9, trade_off=0.08, trade_off1=0.5, trade_off3=0.5, threshold=0.97, rho=0.5, batch_size=3, lr=0.0005, lr_gamma=0.001, lr_decay=0.75, momentum=0.9, weight_decay=0.001, workers=8, epochs=100, early=80, iters_per_epoch=1000, val_interval=5, print_freq=100, seed=None, per_class_eval=False, log='logs/dcase', phase='train', sample_rate=32000, clip_length=10, num_cls=10, device=device(type='cuda'))
# lr: 5e-05
# /home/teaching/miniconda3/lib/python3.12/site-packages/torch/functional.py:730: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at /pytorch/aten/src/ATen/native/SpectralOps.cpp:875.)
#   return _VF.stft(  # type: ignore[attr-defined]
# /home/teaching/miniconda3/lib/python3.12/site-packages/hear21passt/models/preprocess.py:71: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# x torch.Size([6, 1, 128, 1000])
# /home/teaching/miniconda3/lib/python3.12/site-packages/hear21passt/models/passt.py:304: UserWarning: Input image size (128*1000) doesn't match model (128*998).
#   warnings.warn(f"Input image size ({H}*{W}) doesn't match model ({self.img_size[0]}*{self.img_size[1]}).")
# self.norm(x) torch.Size([6, 768, 12, 99])
#  patch_embed :  torch.Size([6, 768, 12, 99])
#  self.time_new_pos_embed.shape torch.Size([1, 768, 1, 99])
#  self.freq_new_pos_embed.shape torch.Size([1, 768, 12, 1])
# X flattened torch.Size([6, 1188, 768])
#  self.new_pos_embed.shape torch.Size([1, 2, 768])
#  self.cls_tokens.shape torch.Size([6, 1, 768])
#  self.dist_token.shape torch.Size([6, 1, 768])
#  final sequence x torch.Size([6, 1190, 768])
#  after 12 atten blocks x torch.Size([6, 1190, 768])
# forward_features torch.Size([6, 768])
# head torch.Size([6, 527])
# /tmp/ipykernel_1311482/1974896290.py:42: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   max_prob, pred_u = torch.max(F.softmax(y_t), dim=-1)
# /home/teaching/miniconda3/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:182: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# /tmp/ipykernel_1311482/1974896290.py:88: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   max_prob, pred_u = torch.max(F.softmax(y_t), dim=-1)
# Epoch: [0][   0/1000]	Time 1.8 (1.8)	Data 0.0 (0.0)	Loss 3.77 (3.77)	Trans Loss 9.70 (9.70)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 0.0 (0.0)
# Epoch: [0][ 100/1000]	Time 1.3 (1.3)	Data 0.4 (0.3)	Loss 2.23 (2.74)	Trans Loss 9.65 (9.65)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (32.3)
# Epoch: [0][ 200/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 2.36 (2.49)	Trans Loss 9.49 (9.59)	CST Loss 0.12 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 33.3 (42.6)
# Epoch: [0][ 300/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 2.09 (2.37)	Trans Loss 9.35 (9.55)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 33.3 (45.6)
# Epoch: [0][ 400/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 2.55 (2.27)	Trans Loss 9.20 (9.51)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 33.3 (48.4)
# Epoch: [0][ 500/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 2.02 (2.23)	Trans Loss 9.31 (9.48)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 33.3 (49.9)
# Epoch: [0][ 600/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 1.52 (2.18)	Trans Loss 9.13 (9.45)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (51.4)
# Epoch: [0][ 700/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 1.88 (2.14)	Trans Loss 9.33 (9.43)	CST Loss 0.12 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 33.3 (52.3)
# Epoch: [0][ 800/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 1.98 (2.10)	Trans Loss 9.45 (9.42)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (53.6)
# Epoch: [0][ 900/1000]	Time 1.4 (1.3)	Data 0.4 (0.3)	Loss 2.99 (2.07)	Trans Loss 9.33 (9.40)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 0.0 (54.4)
# lr: 2.9730177875068026e-05
# Epoch: [1][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.89 (1.89)	Trans Loss 9.32 (9.32)	CST Loss 0.09 (0.09)	Fix Loss 0.00 (0.00)	Cls Acc 33.3 (33.3)
# Epoch: [1][ 100/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 1.65 (1.77)	Trans Loss 8.93 (9.18)	CST Loss 0.13 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (64.7)
# Epoch: [1][ 200/1000]	Time 1.3 (1.3)	Data 0.4 (0.4)	Loss 2.02 (1.79)	Trans Loss 8.96 (9.19)	CST Loss 0.07 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 33.3 (64.3)
# Epoch: [1][ 300/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 1.60 (1.80)	Trans Loss 9.22 (9.19)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (64.6)
# Epoch: [1][ 400/1000]	Time 1.6 (1.3)	Data 0.4 (0.3)	Loss 1.76 (1.81)	Trans Loss 8.73 (9.19)	CST Loss 0.10 (0.10)	Fix Loss 0.07 (0.00)	Cls Acc 66.7 (64.2)
# Epoch: [1][ 500/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 1.47 (1.79)	Trans Loss 9.32 (9.19)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (64.9)
# Epoch: [1][ 600/1000]	Time 1.3 (1.3)	Data 0.4 (0.3)	Loss 1.50 (1.78)	Trans Loss 9.28 (9.18)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (64.8)
# Epoch: [1][ 700/1000]	Time 1.3 (1.3)	Data 0.4 (0.3)	Loss 1.80 (1.78)	Trans Loss 9.28 (9.18)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (64.5)
# Epoch: [1][ 800/1000]	Time 1.5 (1.3)	Data 0.3 (0.3)	Loss 1.63 (1.78)	Trans Loss 9.12 (9.18)	CST Loss 0.11 (0.10)	Fix Loss 0.04 (0.00)	Cls Acc 66.7 (64.6)
# Epoch: [1][ 900/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 1.45 (1.78)	Trans Loss 8.72 (9.17)	CST Loss 0.06 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (64.3)
# lr: 2.1934566882541543e-05
# Epoch: [2][   0/1000]	Time 0.9 (0.9)	Data 0.0 (0.0)	Loss 1.44 (1.44)	Trans Loss 9.62 (9.62)	CST Loss 0.11 (0.11)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (66.7)
# Epoch: [2][ 100/1000]	Time 1.3 (1.3)	Data 0.4 (0.3)	Loss 1.71 (1.68)	Trans Loss 9.20 (9.17)	CST Loss 0.05 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (68.0)
# Epoch: [2][ 200/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 1.71 (1.67)	Trans Loss 9.38 (9.15)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (70.5)
# Epoch: [2][ 300/1000]	Time 1.3 (1.3)	Data 0.4 (0.3)	Loss 1.28 (1.68)	Trans Loss 9.43 (9.15)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (70.4)
# Epoch: [2][ 400/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 1.54 (1.67)	Trans Loss 9.58 (9.15)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (70.2)
# Epoch: [2][ 500/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 1.33 (1.67)	Trans Loss 9.24 (9.15)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (70.1)
# Epoch: [2][ 600/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 1.72 (1.68)	Trans Loss 8.85 (9.14)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (68.9)
# Epoch: [2][ 700/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 1.71 (1.69)	Trans Loss 9.52 (9.14)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (68.0)
# Epoch: [2][ 800/1000]	Time 1.3 (1.3)	Data 0.4 (0.3)	Loss 1.18 (1.70)	Trans Loss 9.37 (9.13)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (67.2)
# Epoch: [2][ 900/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 2.37 (1.69)	Trans Loss 9.08 (9.14)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (67.8)
# lr: 1.7677669529663692e-05
# Epoch: [3][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.48 (1.48)	Trans Loss 8.51 (8.51)	CST Loss 0.09 (0.09)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (66.7)
# Epoch: [3][ 100/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.51 (1.64)	Trans Loss 9.14 (9.09)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (67.0)
# Epoch: [3][ 200/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.67 (1.62)	Trans Loss 9.08 (9.09)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (68.0)
# Epoch: [3][ 300/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.47 (1.63)	Trans Loss 9.20 (9.08)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (68.0)
# Epoch: [3][ 400/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.50 (1.63)	Trans Loss 9.24 (9.08)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (68.9)
# Epoch: [3][ 500/1000]	Time 1.6 (1.3)	Data 0.3 (0.4)	Loss 1.36 (1.63)	Trans Loss 8.71 (9.07)	CST Loss 0.11 (0.10)	Fix Loss 0.03 (0.00)	Cls Acc 100.0 (69.1)
# Epoch: [3][ 600/1000]	Time 1.3 (1.3)	Data 0.4 (0.4)	Loss 1.87 (1.63)	Trans Loss 9.45 (9.07)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (69.4)
# Epoch: [3][ 700/1000]	Time 1.6 (1.3)	Data 0.3 (0.4)	Loss 2.07 (1.64)	Trans Loss 8.49 (9.06)	CST Loss 0.08 (0.10)	Fix Loss 0.03 (0.01)	Cls Acc 66.7 (69.0)
# Epoch: [3][ 800/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.83 (1.63)	Trans Loss 9.10 (9.06)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (69.2)
# Epoch: [3][ 900/1000]	Time 1.3 (1.3)	Data 0.4 (0.4)	Loss 1.10 (1.64)	Trans Loss 8.79 (9.07)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (68.6)
# lr: 1.4953487812212205e-05
# Epoch: [4][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.88 (1.88)	Trans Loss 8.93 (8.93)	CST Loss 0.08 (0.08)	Fix Loss 0.00 (0.00)	Cls Acc 33.3 (33.3)
# Epoch: [4][ 100/1000]	Time 1.5 (1.3)	Data 0.3 (0.3)	Loss 2.04 (1.53)	Trans Loss 8.35 (9.01)	CST Loss 0.08 (0.10)	Fix Loss 0.03 (0.01)	Cls Acc 66.7 (77.2)
# Epoch: [4][ 200/1000]	Time 1.3 (1.3)	Data 0.4 (0.3)	Loss 0.96 (1.62)	Trans Loss 8.66 (9.05)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (72.0)
# Epoch: [4][ 300/1000]	Time 1.3 (1.3)	Data 0.4 (0.3)	Loss 1.47 (1.61)	Trans Loss 8.63 (9.04)	CST Loss 0.12 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (72.2)
# Epoch: [4][ 400/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 1.25 (1.62)	Trans Loss 9.12 (9.05)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (71.3)
# Epoch: [4][ 500/1000]	Time 1.4 (1.3)	Data 0.3 (0.4)	Loss 1.66 (1.62)	Trans Loss 9.03 (9.04)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (71.2)
# Epoch: [4][ 600/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.12 (1.60)	Trans Loss 8.93 (9.04)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (72.0)
# Epoch: [4][ 700/1000]	Time 1.3 (1.3)	Data 0.4 (0.4)	Loss 1.08 (1.60)	Trans Loss 9.11 (9.04)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (71.7)
# Epoch: [4][ 800/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 0.96 (1.59)	Trans Loss 8.87 (9.03)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (71.8)
# Epoch: [4][ 900/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.53 (1.60)	Trans Loss 9.24 (9.03)	CST Loss 0.06 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (71.6)
# Test: [  0/341]	Time  1.493 ( 1.493)	Loss 1.6925e-01 (1.6925e-01)	Acc@1 100.00 (100.00)	Acc@5 100.00 (100.00)
# Test: [100/341]	Time  0.097 ( 0.110)	Loss 1.0956e+00 (7.2575e-01)	Acc@1  33.33 ( 68.98)	Acc@5 100.00 ( 99.67)
# Test: [200/341]	Time  0.096 ( 0.103)	Loss 8.3323e-01 (6.9809e-01)	Acc@1  33.33 ( 71.14)	Acc@5 100.00 ( 99.17)
# Test: [300/341]	Time  0.095 ( 0.101)	Loss 8.3164e-01 (6.7831e-01)	Acc@1  66.67 ( 72.20)	Acc@5 100.00 ( 99.45)
#  * Acc@1 72.407 Acc@5 99.511
#
# Device-specific results:
# Device a: 72.41% (740/1022)
# Test: [  0/125]	Time  1.511 ( 1.511)	Loss 1.4581e+00 (1.4581e+00)	Acc@1  33.33 ( 33.33)	Acc@5 100.00 (100.00)
# Test: [100/125]	Time  0.096 ( 0.110)	Loss 1.6987e+00 (1.0712e+00)	Acc@1   0.00 ( 61.06)	Acc@5 100.00 ( 98.68)
#  * Acc@1 63.467 Acc@5 98.667
#
# Device-specific results:
# Device s3: 68.83% (53/77)
# Device c: 62.32% (43/69)
# Device s2: 71.25% (57/80)
# Device b: 61.25% (49/80)
# Device s1: 52.17% (36/69)
# Best Source Accuracy = 72.4
# Best Target Accuracy = 63.5
# lr: 1.3042371500610729e-05
# Epoch: [5][   0/1000]	Time 0.9 (0.9)	Data 0.0 (0.0)	Loss 1.17 (1.17)	Trans Loss 9.36 (9.36)	CST Loss 0.12 (0.12)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (100.0)
# Epoch: [5][ 100/1000]	Time 1.3 (1.3)	Data 0.4 (0.3)	Loss 1.30 (1.59)	Trans Loss 9.55 (9.01)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (71.3)
# Epoch: [5][ 200/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.26 (1.61)	Trans Loss 8.78 (9.02)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (71.6)
# Epoch: [5][ 300/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.98 (1.61)	Trans Loss 9.05 (9.01)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (71.7)
# Epoch: [5][ 400/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.59 (1.61)	Trans Loss 9.40 (9.01)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (70.9)
# Epoch: [5][ 500/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.22 (1.60)	Trans Loss 9.23 (9.01)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (71.5)
# Epoch: [5][ 600/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.38 (1.60)	Trans Loss 9.52 (9.01)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (71.7)
# Epoch: [5][ 700/1000]	Time 1.5 (1.3)	Data 0.3 (0.4)	Loss 2.38 (1.59)	Trans Loss 8.77 (9.01)	CST Loss 0.11 (0.10)	Fix Loss 1.60 (0.01)	Cls Acc 66.7 (71.5)
# Epoch: [5][ 800/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.65 (1.58)	Trans Loss 8.81 (9.01)	CST Loss 0.12 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (72.1)
# Epoch: [5][ 900/1000]	Time 1.5 (1.3)	Data 0.4 (0.4)	Loss 1.44 (1.59)	Trans Loss 9.16 (9.01)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (71.8)
# lr: 1.1618404012127042e-05
# Epoch: [6][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.62 (1.62)	Trans Loss 9.29 (9.29)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (66.7)
# Epoch: [6][ 100/1000]	Time 1.3 (1.3)	Data 0.3 (0.3)	Loss 2.36 (1.60)	Trans Loss 9.00 (9.01)	CST Loss 0.12 (0.09)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (71.0)
# Epoch: [6][ 200/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 0.91 (1.59)	Trans Loss 8.24 (9.03)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (71.1)
# Epoch: [6][ 300/1000]	Time 1.3 (1.3)	Data 0.4 (0.4)	Loss 1.16 (1.56)	Trans Loss 8.90 (9.02)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (73.5)
# Epoch: [6][ 400/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.02 (1.56)	Trans Loss 9.06 (9.02)	CST Loss 0.12 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (73.2)
# Epoch: [6][ 500/1000]	Time 1.6 (1.3)	Data 0.4 (0.4)	Loss 1.43 (1.56)	Trans Loss 8.42 (9.01)	CST Loss 0.11 (0.10)	Fix Loss 0.01 (0.01)	Cls Acc 100.0 (73.3)
# Epoch: [6][ 600/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 2.44 (1.56)	Trans Loss 9.23 (9.00)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (73.2)
# Epoch: [6][ 700/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.40 (1.54)	Trans Loss 9.12 (9.00)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (73.7)
# Epoch: [6][ 800/1000]	Time 1.5 (1.3)	Data 0.3 (0.4)	Loss 2.01 (1.54)	Trans Loss 8.95 (9.00)	CST Loss 0.11 (0.10)	Fix Loss 0.05 (0.01)	Cls Acc 33.3 (74.1)
# Epoch: [6][ 900/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.81 (1.54)	Trans Loss 8.66 (9.00)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (73.9)
# lr: 1.0511205190671432e-05
# Epoch: [7][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.87 (1.87)	Trans Loss 9.43 (9.43)	CST Loss 0.09 (0.09)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (66.7)
# Epoch: [7][ 100/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.96 (1.60)	Trans Loss 9.11 (8.97)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (70.6)
# Epoch: [7][ 200/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 2.37 (1.55)	Trans Loss 9.09 (8.99)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 0.0 (73.3)
# Epoch: [7][ 300/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.38 (1.54)	Trans Loss 8.80 (8.98)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (74.4)
# Epoch: [7][ 400/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.67 (1.56)	Trans Loss 9.32 (8.98)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (73.2)
# Epoch: [7][ 500/1000]	Time 1.5 (1.3)	Data 0.3 (0.4)	Loss 1.50 (1.54)	Trans Loss 8.13 (8.98)	CST Loss 0.11 (0.10)	Fix Loss 0.09 (0.01)	Cls Acc 66.7 (74.4)
# Epoch: [7][ 600/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.28 (1.54)	Trans Loss 8.87 (8.97)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (74.4)
# Epoch: [7][ 700/1000]	Time 1.3 (1.3)	Data 0.4 (0.4)	Loss 1.35 (1.56)	Trans Loss 9.35 (8.97)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (73.1)
# Epoch: [7][ 800/1000]	Time 1.3 (1.3)	Data 0.4 (0.4)	Loss 1.27 (1.55)	Trans Loss 9.07 (8.96)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (73.0)
# Epoch: [7][ 900/1000]	Time 1.3 (1.3)	Data 0.3 (0.4)	Loss 1.01 (1.56)	Trans Loss 8.93 (8.96)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (72.8)
# lr: 9.622504486493764e-06
# Epoch: [8][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.65 (1.65)	Trans Loss 9.46 (9.46)	CST Loss 0.11 (0.11)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (66.7)
# Epoch: [8][ 100/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.46 (1.50)	Trans Loss 9.30 (8.97)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (72.9)
# Epoch: [8][ 200/1000]	Time 1.3 (1.3)	Data 0.4 (0.4)	Loss 1.44 (1.53)	Trans Loss 8.74 (8.95)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (73.0)
# Epoch: [8][ 300/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.65 (1.52)	Trans Loss 9.03 (8.95)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 33.3 (74.0)
# Epoch: [8][ 400/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.59 (1.49)	Trans Loss 8.88 (8.95)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (75.3)
# Epoch: [8][ 500/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 2.16 (1.51)	Trans Loss 8.80 (8.94)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 33.3 (74.3)
# Epoch: [8][ 600/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.31 (1.52)	Trans Loss 9.13 (8.95)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (73.6)
# Epoch: [8][ 700/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.52 (1.52)	Trans Loss 9.55 (8.95)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (73.8)
# Epoch: [8][ 800/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.57 (1.52)	Trans Loss 9.26 (8.95)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (73.2)
# Epoch: [8][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.59 (1.52)	Trans Loss 9.33 (8.95)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (73.6)
# lr: 8.891397050194615e-06
# Epoch: [9][   0/1000]	Time 1.3 (1.3)	Data 0.0 (0.0)	Loss 1.29 (1.29)	Trans Loss 8.81 (8.81)	CST Loss 0.08 (0.08)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (66.7)
# Epoch: [9][ 100/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 1.21 (1.61)	Trans Loss 8.62 (8.96)	CST Loss 0.11 (0.10)	Fix Loss 0.03 (0.01)	Cls Acc 100.0 (68.0)
# Epoch: [9][ 200/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.96 (1.58)	Trans Loss 9.02 (8.94)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (71.0)
# Epoch: [9][ 300/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.28 (1.54)	Trans Loss 9.48 (8.95)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (72.5)
# Epoch: [9][ 400/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 1.90 (1.54)	Trans Loss 8.60 (8.95)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (73.0)
# Epoch: [9][ 500/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.16 (1.53)	Trans Loss 8.88 (8.93)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (72.9)
# Epoch: [9][ 600/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 2.01 (1.52)	Trans Loss 9.07 (8.94)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (74.0)
# Epoch: [9][ 700/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.23 (1.51)	Trans Loss 8.92 (8.93)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (74.3)
# Epoch: [9][ 800/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.35 (1.51)	Trans Loss 9.15 (8.93)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (74.5)
# Epoch: [9][ 900/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.50 (1.50)	Trans Loss 8.26 (8.93)	CST Loss 0.07 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (74.9)
# Test: [  0/341]	Time  1.490 ( 1.490)	Loss 7.3994e-02 (7.3994e-02)	Acc@1 100.00 (100.00)	Acc@5 100.00 (100.00)
# Test: [100/341]	Time  0.096 ( 0.110)	Loss 1.0220e+00 (6.2181e-01)	Acc@1  33.33 ( 77.23)	Acc@5 100.00 ( 99.67)
# Test: [200/341]	Time  0.096 ( 0.103)	Loss 5.6164e-01 (5.9824e-01)	Acc@1 100.00 ( 78.77)	Acc@5 100.00 ( 99.83)
# Test: [300/341]	Time  0.097 ( 0.101)	Loss 4.9996e-01 (5.9527e-01)	Acc@1 100.00 ( 77.96)	Acc@5 100.00 ( 99.89)
#  * Acc@1 77.691 Acc@5 99.902
#
# Device-specific results:
# Device a: 77.69% (794/1022)
# Test: [  0/125]	Time  1.494 ( 1.494)	Loss 1.5728e+00 (1.5728e+00)	Acc@1  33.33 ( 33.33)	Acc@5 100.00 (100.00)
# Test: [100/125]	Time  0.096 ( 0.110)	Loss 1.4410e+00 (1.0025e+00)	Acc@1  33.33 ( 61.72)	Acc@5 100.00 ( 99.34)
#  * Acc@1 64.000 Acc@5 99.200
#
# Device-specific results:
# Device s3: 66.23% (51/77)
# Device c: 62.32% (43/69)
# Device s2: 71.25% (57/80)
# Device b: 60.00% (48/80)
# Device s1: 59.42% (41/69)
# Best Source Accuracy = 77.7
# Best Target Accuracy = 64.0
# lr: 8.27800130380851e-06
# Epoch: [10][   0/1000]	Time 0.9 (0.9)	Data 0.0 (0.0)	Loss 1.27 (1.27)	Trans Loss 8.59 (8.59)	CST Loss 0.11 (0.11)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (66.7)
# Epoch: [10][ 100/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.74 (1.47)	Trans Loss 8.99 (8.88)	CST Loss 0.07 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (78.5)
# Epoch: [10][ 200/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.68 (1.48)	Trans Loss 9.32 (8.90)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (77.1)
# Epoch: [10][ 300/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.36 (1.46)	Trans Loss 9.51 (8.92)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (77.0)
# Epoch: [10][ 400/1000]	Time 1.5 (1.4)	Data 0.4 (0.4)	Loss 1.62 (1.47)	Trans Loss 8.73 (8.93)	CST Loss 0.08 (0.10)	Fix Loss 0.05 (0.01)	Cls Acc 33.3 (76.6)
# Epoch: [10][ 500/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.95 (1.48)	Trans Loss 8.97 (8.94)	CST Loss 0.06 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (75.9)
# Epoch: [10][ 600/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.58 (1.48)	Trans Loss 9.06 (8.93)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (75.4)
# Epoch: [10][ 700/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.69 (1.48)	Trans Loss 9.28 (8.94)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (75.7)
# Epoch: [10][ 800/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.02 (1.48)	Trans Loss 9.19 (8.94)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (75.8)
# Epoch: [10][ 900/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.72 (1.47)	Trans Loss 8.41 (8.94)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (75.9)
# lr: 7.755040492517498e-06
# Epoch: [11][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 0.85 (0.85)	Trans Loss 8.86 (8.86)	CST Loss 0.08 (0.08)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (100.0)
# Epoch: [11][ 100/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.38 (1.48)	Trans Loss 9.07 (8.89)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (76.6)
# Epoch: [11][ 200/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.24 (1.48)	Trans Loss 9.05 (8.87)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (76.9)
# Epoch: [11][ 300/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.52 (1.48)	Trans Loss 8.84 (8.88)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (75.1)
# Epoch: [11][ 400/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.09 (1.49)	Trans Loss 9.01 (8.91)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (75.0)
# Epoch: [11][ 500/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.40 (1.48)	Trans Loss 9.20 (8.91)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (74.8)
# Epoch: [11][ 600/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.88 (1.51)	Trans Loss 8.97 (8.90)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (73.2)
# Epoch: [11][ 700/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 2.63 (1.52)	Trans Loss 8.99 (8.91)	CST Loss 0.10 (0.10)	Fix Loss 0.05 (0.01)	Cls Acc 0.0 (72.7)
# Epoch: [11][ 800/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 2.02 (1.52)	Trans Loss 9.34 (8.91)	CST Loss 0.06 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (72.9)
# Epoch: [11][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 2.27 (1.51)	Trans Loss 8.72 (8.91)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (73.0)
# lr: 7.3031881619843916e-06
# Epoch: [12][   0/1000]	Time 1.3 (1.3)	Data 0.0 (0.0)	Loss 1.86 (1.86)	Trans Loss 8.62 (8.62)	CST Loss 0.10 (0.10)	Fix Loss 0.03 (0.03)	Cls Acc 66.7 (66.7)
# Epoch: [12][ 100/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.40 (1.51)	Trans Loss 9.39 (8.88)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.03)	Cls Acc 66.7 (75.6)
# Epoch: [12][ 200/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.81 (1.52)	Trans Loss 8.96 (8.91)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (74.0)
# Epoch: [12][ 300/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.42 (1.52)	Trans Loss 8.80 (8.90)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (73.1)
# Epoch: [12][ 400/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.64 (1.50)	Trans Loss 9.03 (8.89)	CST Loss 0.12 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (74.1)
# Epoch: [12][ 500/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 2.18 (1.50)	Trans Loss 8.67 (8.89)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 33.3 (74.5)
# Epoch: [12][ 600/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.86 (1.49)	Trans Loss 8.55 (8.88)	CST Loss 0.10 (0.10)	Fix Loss 0.01 (0.02)	Cls Acc 33.3 (74.9)
# Epoch: [12][ 700/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 2.13 (1.49)	Trans Loss 8.80 (8.88)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (74.8)
# Epoch: [12][ 800/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.68 (1.50)	Trans Loss 9.16 (8.88)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (74.7)
# Epoch: [12][ 900/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.31 (1.50)	Trans Loss 8.70 (8.89)	CST Loss 0.12 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (75.1)
# lr: 6.9083443580988205e-06
# Epoch: [13][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.39 (1.39)	Trans Loss 9.35 (9.35)	CST Loss 0.11 (0.11)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (100.0)
# Epoch: [13][ 100/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.79 (1.42)	Trans Loss 8.80 (8.89)	CST Loss 0.08 (0.10)	Fix Loss 0.49 (0.02)	Cls Acc 66.7 (77.9)
# Epoch: [13][ 200/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.07 (1.43)	Trans Loss 8.47 (8.87)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (78.4)
# Epoch: [13][ 300/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.43 (1.45)	Trans Loss 9.00 (8.89)	CST Loss 0.12 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (76.9)
# Epoch: [13][ 400/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.70 (1.46)	Trans Loss 8.86 (8.89)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 33.3 (76.2)
# Epoch: [13][ 500/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 2.43 (1.48)	Trans Loss 9.01 (8.88)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (75.6)
# Epoch: [13][ 600/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 1.87 (1.47)	Trans Loss 9.29 (8.87)	CST Loss 0.10 (0.10)	Fix Loss 0.13 (0.02)	Cls Acc 33.3 (75.5)
# Epoch: [13][ 700/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.03 (1.46)	Trans Loss 8.92 (8.86)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (76.1)
# Epoch: [13][ 800/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.38 (1.46)	Trans Loss 8.74 (8.87)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (76.0)
# Epoch: [13][ 900/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.44 (1.47)	Trans Loss 8.93 (8.87)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (76.0)
# lr: 6.559965570884769e-06
# Epoch: [14][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.00 (1.00)	Trans Loss 8.77 (8.77)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (100.0)
# Epoch: [14][ 100/1000]	Time 1.5 (1.4)	Data 0.4 (0.4)	Loss 1.17 (1.46)	Trans Loss 9.20 (8.88)	CST Loss 0.11 (0.10)	Fix Loss 0.12 (0.01)	Cls Acc 100.0 (76.2)
# Epoch: [14][ 200/1000]	Time 1.7 (1.4)	Data 0.4 (0.4)	Loss 1.55 (1.44)	Trans Loss 8.81 (8.89)	CST Loss 0.08 (0.10)	Fix Loss 0.04 (0.01)	Cls Acc 66.7 (75.8)
# Epoch: [14][ 300/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.08 (1.44)	Trans Loss 9.04 (8.90)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (76.2)
# Epoch: [14][ 400/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.73 (1.44)	Trans Loss 9.31 (8.90)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (76.6)
# Epoch: [14][ 500/1000]	Time 1.5 (1.4)	Data 0.4 (0.4)	Loss 1.18 (1.45)	Trans Loss 9.02 (8.90)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (76.3)
# Epoch: [14][ 600/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 1.71 (1.45)	Trans Loss 8.70 (8.90)	CST Loss 0.11 (0.10)	Fix Loss 0.02 (0.01)	Cls Acc 33.3 (76.5)
# Epoch: [14][ 700/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.80 (1.45)	Trans Loss 8.88 (8.89)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (76.5)
# Epoch: [14][ 800/1000]	Time 1.7 (1.4)	Data 0.4 (0.4)	Loss 1.72 (1.44)	Trans Loss 8.05 (8.90)	CST Loss 0.11 (0.10)	Fix Loss 0.01 (0.01)	Cls Acc 66.7 (77.1)
# Epoch: [14][ 900/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.09 (1.45)	Trans Loss 8.26 (8.89)	CST Loss 0.11 (0.10)	Fix Loss 0.02 (0.01)	Cls Acc 100.0 (76.7)
# Test: [  0/341]	Time  1.487 ( 1.487)	Loss 1.0987e-01 (1.0987e-01)	Acc@1 100.00 (100.00)	Acc@5 100.00 (100.00)
# Test: [100/341]	Time  0.096 ( 0.110)	Loss 1.3897e+00 (5.9865e-01)	Acc@1  33.33 ( 78.88)	Acc@5 100.00 (100.00)
# Test: [200/341]	Time  0.096 ( 0.103)	Loss 5.2556e-01 (5.7121e-01)	Acc@1 100.00 ( 79.27)	Acc@5 100.00 ( 99.67)
# Test: [300/341]	Time  0.096 ( 0.101)	Loss 4.9616e-01 (5.6472e-01)	Acc@1 100.00 ( 79.29)	Acc@5 100.00 ( 99.78)
#  * Acc@1 79.159 Acc@5 99.804
#
# Device-specific results:
# Device a: 79.16% (809/1022)
# Test: [  0/125]	Time  1.519 ( 1.519)	Loss 1.1825e+00 (1.1825e+00)	Acc@1  33.33 ( 33.33)	Acc@5 100.00 (100.00)
# Test: [100/125]	Time  0.096 ( 0.110)	Loss 1.2806e+00 (1.0474e+00)	Acc@1  33.33 ( 61.72)	Acc@5 100.00 ( 98.35)
#  * Acc@1 64.000 Acc@5 98.400
#
# Device-specific results:
# Device s3: 67.53% (52/77)
# Device c: 68.12% (47/69)
# Device s2: 71.25% (57/80)
# Device b: 62.50% (50/80)
# Device s1: 49.28% (34/69)
# Best Source Accuracy = 79.2
# Best Target Accuracy = 64.0
# lr: 6.25e-06
# Epoch: [15][   0/1000]	Time 0.9 (0.9)	Data 0.0 (0.0)	Loss 0.95 (0.95)	Trans Loss 8.98 (8.98)	CST Loss 0.11 (0.11)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (100.0)
# Epoch: [15][ 100/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.63 (1.38)	Trans Loss 8.47 (8.93)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (78.5)
# Epoch: [15][ 200/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.60 (1.45)	Trans Loss 9.07 (8.91)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (73.8)
# Epoch: [15][ 300/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.76 (1.47)	Trans Loss 9.01 (8.91)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (74.2)
# Epoch: [15][ 400/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 2.03 (1.47)	Trans Loss 8.77 (8.89)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 33.3 (74.3)
# Epoch: [15][ 500/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 2.03 (1.45)	Trans Loss 8.94 (8.89)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 0.0 (75.3)
# Epoch: [15][ 600/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.21 (1.45)	Trans Loss 9.01 (8.89)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (75.7)
# Epoch: [15][ 700/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.47 (1.46)	Trans Loss 9.18 (8.89)	CST Loss 0.10 (0.10)	Fix Loss 0.02 (0.02)	Cls Acc 100.0 (75.7)
# Epoch: [15][ 800/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.52 (1.46)	Trans Loss 9.10 (8.88)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (75.7)
# Epoch: [15][ 900/1000]	Time 1.7 (1.4)	Data 0.4 (0.4)	Loss 2.00 (1.46)	Trans Loss 8.12 (8.88)	CST Loss 0.09 (0.10)	Fix Loss 0.03 (0.02)	Cls Acc 33.3 (75.8)
# lr: 5.972185837849797e-06
# Epoch: [16][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.54 (1.54)	Trans Loss 8.81 (8.81)	CST Loss 0.07 (0.07)	Fix Loss 0.00 (0.00)	Cls Acc 33.3 (33.3)
# Epoch: [16][ 100/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.27 (1.39)	Trans Loss 9.07 (8.88)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (78.2)
# Epoch: [16][ 200/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.36 (1.41)	Trans Loss 9.05 (8.89)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (76.9)
# Epoch: [16][ 300/1000]	Time 1.5 (1.4)	Data 0.3 (0.4)	Loss 1.71 (1.43)	Trans Loss 8.97 (8.89)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (76.0)
# Epoch: [16][ 400/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.18 (1.45)	Trans Loss 8.71 (8.89)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (75.6)
# Epoch: [16][ 500/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 1.54 (1.45)	Trans Loss 8.32 (8.88)	CST Loss 0.12 (0.10)	Fix Loss 0.04 (0.01)	Cls Acc 66.7 (75.7)
# Epoch: [16][ 600/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 2.16 (1.45)	Trans Loss 8.73 (8.87)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (75.7)
# Epoch: [16][ 700/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.30 (1.45)	Trans Loss 8.47 (8.87)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (76.1)
# Epoch: [16][ 800/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.45 (1.45)	Trans Loss 9.33 (8.87)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (76.1)
# Epoch: [16][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.72 (1.45)	Trans Loss 9.42 (8.87)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (76.2)
# lr: 5.721575399741995e-06
# Epoch: [17][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 0.97 (0.97)	Trans Loss 8.82 (8.82)	CST Loss 0.08 (0.08)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (100.0)
# Epoch: [17][ 100/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 2.91 (1.37)	Trans Loss 8.83 (8.88)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (80.2)
# Epoch: [17][ 200/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 2.16 (1.43)	Trans Loss 8.53 (8.87)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 33.3 (78.1)
# Epoch: [17][ 300/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 1.13 (1.44)	Trans Loss 8.85 (8.88)	CST Loss 0.08 (0.10)	Fix Loss 0.04 (0.02)	Cls Acc 100.0 (77.2)
# Epoch: [17][ 400/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.27 (1.45)	Trans Loss 9.13 (8.88)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (76.1)
# Epoch: [17][ 500/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.04 (1.44)	Trans Loss 8.53 (8.88)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (76.4)
# Epoch: [17][ 600/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 0.90 (1.43)	Trans Loss 8.56 (8.87)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (77.6)
# Epoch: [17][ 700/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 0.93 (1.45)	Trans Loss 8.80 (8.87)	CST Loss 0.05 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (77.0)
# Epoch: [17][ 800/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.27 (1.45)	Trans Loss 8.87 (8.87)	CST Loss 0.12 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (77.1)
# Epoch: [17][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.33 (1.45)	Trans Loss 9.25 (8.87)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (77.1)
# lr: 5.494204289289063e-06
# Epoch: [18][   0/1000]	Time 0.9 (0.9)	Data 0.0 (0.0)	Loss 0.99 (0.99)	Trans Loss 9.28 (9.28)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (100.0)
# Epoch: [18][ 100/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.18 (1.38)	Trans Loss 8.50 (8.86)	CST Loss 0.10 (0.10)	Fix Loss 0.02 (0.01)	Cls Acc 100.0 (80.2)
# Epoch: [18][ 200/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 0.93 (1.41)	Trans Loss 9.30 (8.84)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (78.9)
# Epoch: [18][ 300/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.28 (1.43)	Trans Loss 9.03 (8.85)	CST Loss 0.04 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (77.3)
# Epoch: [18][ 400/1000]	Time 1.5 (1.4)	Data 0.4 (0.4)	Loss 1.77 (1.42)	Trans Loss 9.04 (8.86)	CST Loss 0.05 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (77.2)
# Epoch: [18][ 500/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 1.27 (1.42)	Trans Loss 8.16 (8.86)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (76.8)
# Epoch: [18][ 600/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 1.50 (1.42)	Trans Loss 8.52 (8.86)	CST Loss 0.10 (0.10)	Fix Loss 0.10 (0.01)	Cls Acc 66.7 (76.6)
# Epoch: [18][ 700/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.36 (1.42)	Trans Loss 8.94 (8.87)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (77.0)
# Epoch: [18][ 800/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.43 (1.42)	Trans Loss 8.86 (8.87)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (77.4)
# Epoch: [18][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.12 (1.43)	Trans Loss 9.38 (8.87)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (77.2)
# lr: 5.286856317202821e-06
# Epoch: [19][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.83 (1.83)	Trans Loss 9.31 (9.31)	CST Loss 0.09 (0.09)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (66.7)
# Epoch: [19][ 100/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.04 (1.42)	Trans Loss 8.76 (8.86)	CST Loss 0.09 (0.09)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (75.6)
# Epoch: [19][ 200/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.36 (1.44)	Trans Loss 9.18 (8.87)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (76.6)
# Epoch: [19][ 300/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.39 (1.42)	Trans Loss 9.08 (8.87)	CST Loss 0.11 (0.09)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (78.0)
# Epoch: [19][ 400/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.23 (1.42)	Trans Loss 8.45 (8.86)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (78.1)
# Epoch: [19][ 500/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.55 (1.42)	Trans Loss 9.21 (8.86)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (77.6)
# Epoch: [19][ 600/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 0.99 (1.41)	Trans Loss 9.00 (8.86)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (78.1)
# Epoch: [19][ 700/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.31 (1.42)	Trans Loss 8.71 (8.85)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (77.6)
# Epoch: [19][ 800/1000]	Time 1.5 (1.4)	Data 0.4 (0.4)	Loss 1.22 (1.41)	Trans Loss 8.69 (8.85)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (78.0)
# Epoch: [19][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.19 (1.41)	Trans Loss 8.64 (8.86)	CST Loss 0.07 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (78.2)
# Test: [  0/341]	Time  1.497 ( 1.497)	Loss 1.3980e-01 (1.3980e-01)	Acc@1 100.00 (100.00)	Acc@5 100.00 (100.00)
# Test: [100/341]	Time  0.096 ( 0.110)	Loss 1.2678e+00 (5.6729e-01)	Acc@1  33.33 ( 80.20)	Acc@5 100.00 (100.00)
# Test: [200/341]	Time  0.095 ( 0.103)	Loss 5.9296e-01 (5.4130e-01)	Acc@1  66.67 ( 80.27)	Acc@5 100.00 (100.00)
# Test: [300/341]	Time  0.096 ( 0.101)	Loss 4.8181e-01 (5.3136e-01)	Acc@1 100.00 ( 80.29)	Acc@5 100.00 (100.00)
#  * Acc@1 79.843 Acc@5 100.000
#
# Device-specific results:
# Device a: 79.84% (816/1022)
# Test: [  0/125]	Time  1.500 ( 1.500)	Loss 1.0536e+00 (1.0536e+00)	Acc@1  66.67 ( 66.67)	Acc@5 100.00 (100.00)
# Test: [100/125]	Time  0.097 ( 0.110)	Loss 1.5411e+00 (9.6616e-01)	Acc@1  33.33 ( 65.68)	Acc@5 100.00 ( 98.68)
#  * Acc@1 66.667 Acc@5 98.667
#
# Device-specific results:
# Device s3: 70.13% (54/77)
# Device c: 72.46% (50/69)
# Device s2: 73.75% (59/80)
# Device b: 61.25% (49/80)
# Device s1: 55.07% (38/69)
# Best Source Accuracy = 79.8
# Best Target Accuracy = 66.7
# lr: 5.096893197447791e-06
# Epoch: [20][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.41 (1.41)	Trans Loss 8.83 (8.83)	CST Loss 0.11 (0.11)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (66.7)
# Epoch: [20][ 100/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.19 (1.38)	Trans Loss 8.58 (8.94)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (81.2)
# Epoch: [20][ 200/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 2.30 (1.41)	Trans Loss 8.54 (8.89)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (78.3)
# Epoch: [20][ 300/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.11 (1.41)	Trans Loss 9.15 (8.89)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (77.7)
# Epoch: [20][ 400/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.42 (1.41)	Trans Loss 9.29 (8.89)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (77.3)
# Epoch: [20][ 500/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 1.41 (1.41)	Trans Loss 9.04 (8.89)	CST Loss 0.09 (0.10)	Fix Loss 0.02 (0.01)	Cls Acc 66.7 (78.0)
# Epoch: [20][ 600/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.01 (1.41)	Trans Loss 9.15 (8.89)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (78.1)
# Epoch: [20][ 700/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.03 (1.43)	Trans Loss 8.49 (8.89)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (77.1)
# Epoch: [20][ 800/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.47 (1.42)	Trans Loss 8.59 (8.87)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (77.5)
# Epoch: [20][ 900/1000]	Time 1.5 (1.4)	Data 0.4 (0.4)	Loss 1.36 (1.43)	Trans Loss 8.50 (8.87)	CST Loss 0.11 (0.10)	Fix Loss 0.10 (0.01)	Cls Acc 100.0 (77.4)
# lr: 4.922129024245441e-06
# Epoch: [21][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.26 (1.26)	Trans Loss 8.97 (8.97)	CST Loss 0.12 (0.12)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (100.0)
# Epoch: [21][ 100/1000]	Time 1.7 (1.4)	Data 0.4 (0.4)	Loss 1.52 (1.47)	Trans Loss 8.60 (8.84)	CST Loss 0.12 (0.10)	Fix Loss 0.01 (0.02)	Cls Acc 66.7 (75.2)
# Epoch: [21][ 200/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.23 (1.47)	Trans Loss 8.99 (8.86)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (74.8)
# Epoch: [21][ 300/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 1.48 (1.44)	Trans Loss 8.96 (8.87)	CST Loss 0.11 (0.10)	Fix Loss 0.01 (0.01)	Cls Acc 66.7 (76.0)
# Epoch: [21][ 400/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.06 (1.43)	Trans Loss 9.16 (8.85)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (76.4)
# Epoch: [21][ 500/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.04 (1.43)	Trans Loss 8.47 (8.83)	CST Loss 0.11 (0.10)	Fix Loss 0.01 (0.01)	Cls Acc 100.0 (76.5)
# Epoch: [21][ 600/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.63 (1.42)	Trans Loss 9.29 (8.82)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (77.0)
# Epoch: [21][ 700/1000]	Time 1.7 (1.4)	Data 0.4 (0.4)	Loss 1.59 (1.41)	Trans Loss 7.93 (8.82)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (77.3)
# Epoch: [21][ 800/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 2.02 (1.41)	Trans Loss 9.19 (8.83)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (77.3)
# Epoch: [21][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.43 (1.42)	Trans Loss 8.74 (8.83)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (77.4)
# lr: 4.760736311075744e-06
# Epoch: [22][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.30 (1.30)	Trans Loss 8.04 (8.04)	CST Loss 0.08 (0.08)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (66.7)
# Epoch: [22][ 100/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.28 (1.32)	Trans Loss 9.38 (8.83)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.03)	Cls Acc 66.7 (82.8)
# Epoch: [22][ 200/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 0.96 (1.37)	Trans Loss 9.02 (8.84)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (79.8)
# Epoch: [22][ 300/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 1.26 (1.40)	Trans Loss 8.34 (8.84)	CST Loss 0.08 (0.10)	Fix Loss 0.02 (0.02)	Cls Acc 100.0 (79.3)
# Epoch: [22][ 400/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 2.49 (1.41)	Trans Loss 9.02 (8.84)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 33.3 (78.6)
# Epoch: [22][ 500/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 0.79 (1.41)	Trans Loss 8.65 (8.84)	CST Loss 0.05 (0.10)	Fix Loss 0.01 (0.02)	Cls Acc 100.0 (78.4)
# Epoch: [22][ 600/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.14 (1.42)	Trans Loss 8.52 (8.84)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (77.5)
# Epoch: [22][ 700/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.31 (1.41)	Trans Loss 8.98 (8.84)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (78.1)
# Epoch: [22][ 800/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.20 (1.41)	Trans Loss 8.86 (8.84)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (77.9)
# Epoch: [22][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 2.24 (1.41)	Trans Loss 8.99 (8.84)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (78.2)
# lr: 4.611174665418007e-06
# Epoch: [23][   0/1000]	Time 0.9 (0.9)	Data 0.0 (0.0)	Loss 0.85 (0.85)	Trans Loss 8.79 (8.79)	CST Loss 0.09 (0.09)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (100.0)
# Epoch: [23][ 100/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.69 (1.42)	Trans Loss 9.50 (8.86)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (78.9)
# Epoch: [23][ 200/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.39 (1.39)	Trans Loss 8.89 (8.86)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (78.8)
# Epoch: [23][ 300/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.68 (1.39)	Trans Loss 8.98 (8.85)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (79.1)
# Epoch: [23][ 400/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.24 (1.40)	Trans Loss 8.96 (8.84)	CST Loss 0.06 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (79.3)
# Epoch: [23][ 500/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.19 (1.41)	Trans Loss 9.05 (8.85)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (78.5)
# Epoch: [23][ 600/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.76 (1.41)	Trans Loss 8.58 (8.85)	CST Loss 0.09 (0.10)	Fix Loss 0.01 (0.01)	Cls Acc 33.3 (78.5)
# Epoch: [23][ 700/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.68 (1.41)	Trans Loss 8.30 (8.85)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 33.3 (78.7)
# Epoch: [23][ 800/1000]	Time 1.7 (1.4)	Data 0.4 (0.4)	Loss 0.94 (1.40)	Trans Loss 8.91 (8.85)	CST Loss 0.11 (0.10)	Fix Loss 0.01 (0.02)	Cls Acc 100.0 (78.9)
# Epoch: [23][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.21 (1.40)	Trans Loss 9.12 (8.84)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (78.7)
# lr: 4.47213595499958e-06
# Epoch: [24][   0/1000]	Time 0.9 (0.9)	Data 0.0 (0.0)	Loss 1.05 (1.05)	Trans Loss 9.01 (9.01)	CST Loss 0.09 (0.09)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (100.0)
# Epoch: [24][ 100/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.85 (1.41)	Trans Loss 9.01 (8.85)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (78.5)
# Epoch: [24][ 200/1000]	Time 1.7 (1.4)	Data 0.4 (0.4)	Loss 1.54 (1.39)	Trans Loss 8.70 (8.83)	CST Loss 0.10 (0.10)	Fix Loss 0.18 (0.01)	Cls Acc 66.7 (77.6)
# Epoch: [24][ 300/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 2.49 (1.37)	Trans Loss 9.23 (8.83)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (79.3)
# Epoch: [24][ 400/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.54 (1.39)	Trans Loss 8.78 (8.84)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (78.6)
# Epoch: [24][ 500/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.12 (1.40)	Trans Loss 8.63 (8.83)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (77.2)
# Epoch: [24][ 600/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.53 (1.40)	Trans Loss 9.04 (8.83)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (77.4)
# Epoch: [24][ 700/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.43 (1.40)	Trans Loss 8.30 (8.83)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (77.7)
# Epoch: [24][ 800/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.03 (1.40)	Trans Loss 8.86 (8.84)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (78.2)
# Epoch: [24][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.50 (1.41)	Trans Loss 8.61 (8.84)	CST Loss 0.06 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (78.1)
# Test: [  0/341]	Time  1.508 ( 1.508)	Loss 1.0999e-01 (1.0999e-01)	Acc@1 100.00 (100.00)	Acc@5 100.00 (100.00)
# Test: [100/341]	Time  0.096 ( 0.110)	Loss 1.2605e+00 (5.3028e-01)	Acc@1  33.33 ( 81.52)	Acc@5 100.00 (100.00)
# Test: [200/341]	Time  0.096 ( 0.103)	Loss 4.7218e-01 (5.1536e-01)	Acc@1 100.00 ( 82.42)	Acc@5 100.00 (100.00)
# Test: [300/341]	Time  0.096 ( 0.101)	Loss 4.4358e-01 (5.0912e-01)	Acc@1 100.00 ( 81.62)	Acc@5 100.00 (100.00)
#  * Acc@1 81.311 Acc@5 100.000
#
# Device-specific results:
# Device a: 81.31% (831/1022)
# Test: [  0/125]	Time  1.533 ( 1.533)	Loss 1.2338e+00 (1.2338e+00)	Acc@1  33.33 ( 33.33)	Acc@5 100.00 (100.00)
# Test: [100/125]	Time  0.096 ( 0.110)	Loss 1.5771e+00 (9.3626e-01)	Acc@1  33.33 ( 65.02)	Acc@5 100.00 ( 99.01)
#  * Acc@1 66.933 Acc@5 98.933
#
# Device-specific results:
# Device s3: 67.53% (52/77)
# Device c: 71.01% (49/69)
# Device s2: 78.75% (63/80)
# Device b: 61.25% (49/80)
# Device s1: 55.07% (38/69)
# Best Source Accuracy = 81.3
# Best Target Accuracy = 66.9
# lr: 4.342501662217742e-06
# Epoch: [25][   0/1000]	Time 1.3 (1.3)	Data 0.0 (0.0)	Loss 1.40 (1.40)	Trans Loss 8.89 (8.89)	CST Loss 0.08 (0.08)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (66.7)
# Epoch: [25][ 100/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.50 (1.33)	Trans Loss 8.69 (8.81)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (81.8)
# Epoch: [25][ 200/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.93 (1.37)	Trans Loss 8.70 (8.83)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (77.9)
# Epoch: [25][ 300/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 0.89 (1.35)	Trans Loss 8.06 (8.82)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (80.1)
# ...
# Epoch: [72][ 200/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 0.98 (1.26)	Trans Loss 8.83 (8.75)	CST Loss 0.12 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (84.1)
# Epoch: [72][ 300/1000]	Time 1.7 (1.4)	Data 0.4 (0.4)	Loss 1.40 (1.27)	Trans Loss 9.01 (8.77)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (83.2)
# Epoch: [72][ 400/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.38 (1.28)	Trans Loss 8.78 (8.78)	CST Loss 0.12 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (83.1)
# Epoch: [72][ 500/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.42 (1.26)	Trans Loss 8.97 (8.77)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (83.4)
# Epoch: [72][ 600/1000]	Time 1.7 (1.4)	Data 0.4 (0.4)	Loss 1.65 (1.27)	Trans Loss 8.19 (8.76)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (83.5)
# Epoch: [72][ 700/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.13 (1.27)	Trans Loss 8.79 (8.75)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (83.4)
# Epoch: [72][ 800/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 0.90 (1.27)	Trans Loss 8.58 (8.75)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (83.3)
# Epoch: [72][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.93 (1.27)	Trans Loss 9.14 (8.74)	CST Loss 0.06 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 33.3 (83.2)
# lr: 1.9817378970733236e-06
# Epoch: [73][   0/1000]	Time 0.9 (0.9)	Data 0.0 (0.0)	Loss 2.05 (2.05)	Trans Loss 8.92 (8.92)	CST Loss 0.11 (0.11)	Fix Loss 0.00 (0.00)	Cls Acc 33.3 (33.3)
# Epoch: [73][ 100/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 1.46 (1.26)	Trans Loss 7.99 (8.72)	CST Loss 0.07 (0.10)	Fix Loss 0.01 (0.02)	Cls Acc 33.3 (82.8)
# Epoch: [73][ 200/1000]	Time 1.5 (1.4)	Data 0.4 (0.4)	Loss 1.54 (1.30)	Trans Loss 9.04 (8.76)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (82.4)
# Epoch: [73][ 300/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.03 (1.30)	Trans Loss 8.90 (8.74)	CST Loss 0.10 (0.10)	Fix Loss 0.07 (0.02)	Cls Acc 100.0 (82.6)
# Epoch: [73][ 400/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.59 (1.30)	Trans Loss 8.90 (8.71)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 33.3 (81.7)
# Epoch: [73][ 500/1000]	Time 1.7 (1.4)	Data 0.4 (0.4)	Loss 1.36 (1.30)	Trans Loss 7.90 (8.71)	CST Loss 0.11 (0.10)	Fix Loss 0.03 (0.03)	Cls Acc 66.7 (81.8)
# Epoch: [73][ 600/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.00 (1.30)	Trans Loss 9.08 (8.71)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (81.7)
# Epoch: [73][ 700/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.06 (1.29)	Trans Loss 9.05 (8.72)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (82.0)
# Epoch: [73][ 800/1000]	Time 1.7 (1.4)	Data 0.4 (0.4)	Loss 1.14 (1.30)	Trans Loss 8.33 (8.72)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.03)	Cls Acc 66.7 (82.1)
# Epoch: [73][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 0.92 (1.30)	Trans Loss 8.84 (8.73)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (82.0)
# lr: 1.9618873042551415e-06
# Epoch: [74][   0/1000]	Time 1.3 (1.3)	Data 0.0 (0.0)	Loss 1.45 (1.45)	Trans Loss 8.64 (8.64)	CST Loss 0.11 (0.11)	Fix Loss 0.20 (0.20)	Cls Acc 66.7 (66.7)
# Epoch: [74][ 100/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 0.95 (1.29)	Trans Loss 8.55 (8.72)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (82.2)
# Epoch: [74][ 200/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.42 (1.32)	Trans Loss 8.83 (8.72)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (79.9)
# Epoch: [74][ 300/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.05 (1.31)	Trans Loss 8.24 (8.73)	CST Loss 0.06 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (81.3)
# Epoch: [74][ 400/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.34 (1.28)	Trans Loss 8.96 (8.73)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (83.0)
# Epoch: [74][ 500/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.24 (1.28)	Trans Loss 8.07 (8.73)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (82.7)
# Epoch: [74][ 600/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 2.11 (1.29)	Trans Loss 8.93 (8.73)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (82.9)
# Epoch: [74][ 700/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.23 (1.28)	Trans Loss 8.75 (8.74)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (83.0)
# Epoch: [74][ 800/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 0.90 (1.27)	Trans Loss 8.76 (8.73)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (83.4)
# Epoch: [74][ 900/1000]	Time 1.5 (1.4)	Data 0.4 (0.4)	Loss 1.45 (1.27)	Trans Loss 8.78 (8.73)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (83.4)
# Test: [  0/341]	Time  1.503 ( 1.503)	Loss 9.0766e-02 (9.0766e-02)	Acc@1 100.00 (100.00)	Acc@5 100.00 (100.00)
# Test: [100/341]	Time  0.097 ( 0.110)	Loss 1.2736e+00 (4.3212e-01)	Acc@1  33.33 ( 84.49)	Acc@5 100.00 (100.00)
# Test: [200/341]	Time  0.096 ( 0.103)	Loss 2.4411e-01 (4.2208e-01)	Acc@1 100.00 ( 84.74)	Acc@5 100.00 (100.00)
# Test: [300/341]	Time  0.096 ( 0.101)	Loss 2.3941e-01 (4.1126e-01)	Acc@1 100.00 ( 85.16)	Acc@5 100.00 (100.00)
#  * Acc@1 84.736 Acc@5 100.000
#
# Device-specific results:
# Device a: 84.74% (866/1022)
# Test: [  0/125]	Time  1.518 ( 1.518)	Loss 9.0041e-01 (9.0041e-01)	Acc@1  66.67 ( 66.67)	Acc@5 100.00 (100.00)
# Test: [100/125]	Time  0.096 ( 0.110)	Loss 1.1708e+00 (1.1370e+00)	Acc@1  33.33 ( 60.40)	Acc@5 100.00 ( 98.35)
#  * Acc@1 60.800 Acc@5 98.400
#
# Device-specific results:
# Device s3: 67.53% (52/77)
# Device c: 75.36% (52/69)
# Device s2: 60.00% (48/80)
# Device b: 60.00% (48/80)
# Device s1: 40.58% (28/69)
# Best Source Accuracy = 85.0
# Best Target Accuracy = 67.7
# lr: 1.9424945550902563e-06
# Epoch: [75][   0/1000]	Time 0.9 (0.9)	Data 0.0 (0.0)	Loss 0.77 (0.77)	Trans Loss 8.80 (8.80)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (100.0)
# Epoch: [75][ 100/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.76 (1.31)	Trans Loss 7.95 (8.76)	CST Loss 0.09 (0.09)	Fix Loss 0.00 (0.02)	Cls Acc 33.3 (79.2)
# Epoch: [75][ 200/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.30 (1.26)	Trans Loss 8.04 (8.73)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (82.9)
# Epoch: [75][ 300/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.05 (1.26)	Trans Loss 8.75 (8.72)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (83.6)
# Epoch: [75][ 400/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 2.04 (1.26)	Trans Loss 7.73 (8.72)	CST Loss 0.07 (0.10)	Fix Loss 0.01 (0.02)	Cls Acc 66.7 (83.6)
# Epoch: [75][ 500/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 0.81 (1.26)	Trans Loss 8.31 (8.71)	CST Loss 0.12 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (83.8)
# Epoch: [75][ 600/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 0.94 (1.27)	Trans Loss 8.48 (8.71)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (83.8)
# Epoch: [75][ 700/1000]	Time 1.7 (1.4)	Data 0.4 (0.4)	Loss 1.40 (1.26)	Trans Loss 8.55 (8.72)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (84.3)
# Epoch: [75][ 800/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.54 (1.27)	Trans Loss 8.72 (8.73)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (83.9)
# Epoch: [75][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 0.80 (1.27)	Trans Loss 8.72 (8.73)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (84.1)
# lr: 1.9235432712112333e-06
# Epoch: [76][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.32 (1.32)	Trans Loss 8.74 (8.74)	CST Loss 0.11 (0.11)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (100.0)
# Epoch: [76][ 100/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.33 (1.32)	Trans Loss 8.83 (8.76)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (80.5)
# Epoch: [76][ 200/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 0.86 (1.29)	Trans Loss 9.29 (8.76)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (81.9)
# Epoch: [76][ 300/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.64 (1.29)	Trans Loss 9.00 (8.74)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.03)	Cls Acc 33.3 (82.4)
# Epoch: [76][ 400/1000]	Time 1.7 (1.4)	Data 0.4 (0.4)	Loss 1.20 (1.27)	Trans Loss 8.57 (8.73)	CST Loss 0.06 (0.10)	Fix Loss 0.03 (0.02)	Cls Acc 100.0 (83.0)
# Epoch: [76][ 500/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.17 (1.26)	Trans Loss 9.48 (8.73)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (83.8)
# Epoch: [76][ 600/1000]	Time 2.9 (1.4)	Data 1.6 (0.4)	Loss 0.97 (1.26)	Trans Loss 8.42 (8.72)	CST Loss 0.10 (0.10)	Fix Loss 0.01 (0.02)	Cls Acc 100.0 (83.5)
# Epoch: [76][ 700/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 0.95 (1.26)	Trans Loss 8.09 (8.72)	CST Loss 0.06 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 100.0 (83.3)
# Epoch: [76][ 800/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.50 (1.26)	Trans Loss 9.16 (8.72)	CST Loss 0.10 (0.10)	Fix Loss 0.25 (0.02)	Cls Acc 100.0 (83.4)
# Epoch: [76][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.63 (1.26)	Trans Loss 8.44 (8.72)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.02)	Cls Acc 66.7 (83.6)
# lr: 1.9050178629492575e-06
# Epoch: [77][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 0.82 (0.82)	Trans Loss 9.03 (9.03)	CST Loss 0.08 (0.08)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (100.0)
# Epoch: [77][ 100/1000]	Time 1.5 (1.4)	Data 0.4 (0.4)	Loss 1.95 (1.28)	Trans Loss 8.44 (8.76)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.00)	Cls Acc 66.7 (84.2)
# Epoch: [77][ 200/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.04 (1.28)	Trans Loss 8.91 (8.75)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (83.4)
# Epoch: [77][ 300/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.42 (1.25)	Trans Loss 9.04 (8.73)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (84.1)
# Epoch: [77][ 400/1000]	Time 1.5 (1.4)	Data 0.4 (0.4)	Loss 1.14 (1.26)	Trans Loss 8.10 (8.73)	CST Loss 0.11 (0.10)	Fix Loss 0.01 (0.01)	Cls Acc 100.0 (83.6)
# Epoch: [77][ 500/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.40 (1.25)	Trans Loss 8.92 (8.73)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (83.9)
# Epoch: [77][ 600/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.12 (1.25)	Trans Loss 8.44 (8.73)	CST Loss 0.06 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (83.9)
# Epoch: [77][ 700/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 0.85 (1.26)	Trans Loss 8.59 (8.73)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (83.8)
# Epoch: [77][ 800/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 1.13 (1.26)	Trans Loss 8.84 (8.73)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (83.6)
# Epoch: [77][ 900/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 0.84 (1.26)	Trans Loss 8.92 (8.73)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (83.6)
# lr: 1.8869034818362857e-06
# Epoch: [78][   0/1000]	Time 1.3 (1.3)	Data 0.0 (0.0)	Loss 1.50 (1.50)	Trans Loss 8.74 (8.74)	CST Loss 0.06 (0.06)	Fix Loss 0.01 (0.01)	Cls Acc 66.7 (66.7)
# Epoch: [78][ 100/1000]	Time 1.5 (1.4)	Data 0.4 (0.4)	Loss 1.03 (1.23)	Trans Loss 8.83 (8.70)	CST Loss 0.09 (0.09)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (83.5)
# Epoch: [78][ 200/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.21 (1.22)	Trans Loss 8.73 (8.72)	CST Loss 0.10 (0.09)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (84.1)
# Epoch: [78][ 300/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.56 (1.25)	Trans Loss 8.71 (8.72)	CST Loss 0.11 (0.09)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (82.9)
# Epoch: [78][ 400/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.15 (1.25)	Trans Loss 8.90 (8.72)	CST Loss 0.08 (0.09)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (83.5)
# Epoch: [78][ 500/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.16 (1.26)	Trans Loss 9.10 (8.71)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (83.1)
# Epoch: [78][ 600/1000]	Time 1.6 (1.4)	Data 0.4 (0.4)	Loss 1.03 (1.25)	Trans Loss 8.87 (8.72)	CST Loss 0.11 (0.10)	Fix Loss 0.01 (0.01)	Cls Acc 100.0 (83.9)
# Epoch: [78][ 700/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.15 (1.25)	Trans Loss 9.07 (8.72)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (84.0)
# Epoch: [78][ 800/1000]	Time 1.5 (1.4)	Data 0.4 (0.4)	Loss 1.46 (1.25)	Trans Loss 8.76 (8.72)	CST Loss 0.10 (0.10)	Fix Loss 0.54 (0.02)	Cls Acc 100.0 (83.7)
# Epoch: [78][ 900/1000]	Time 1.6 (1.4)	Data 0.3 (0.4)	Loss 1.26 (1.25)	Trans Loss 8.33 (8.72)	CST Loss 0.10 (0.10)	Fix Loss 0.12 (0.02)	Cls Acc 100.0 (83.5)
# lr: 1.8691859765265256e-06
# Epoch: [79][   0/1000]	Time 1.0 (1.0)	Data 0.0 (0.0)	Loss 1.03 (1.03)	Trans Loss 8.39 (8.39)	CST Loss 0.09 (0.09)	Fix Loss 0.00 (0.00)	Cls Acc 100.0 (100.0)
# Epoch: [79][ 100/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.71 (1.25)	Trans Loss 8.72 (8.79)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (84.8)
# Epoch: [79][ 200/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 0.95 (1.26)	Trans Loss 8.96 (8.76)	CST Loss 0.09 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (84.1)
# Epoch: [79][ 300/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 1.40 (1.26)	Trans Loss 8.78 (8.74)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (84.3)
# Epoch: [79][ 400/1000]	Time 1.5 (1.4)	Data 0.4 (0.4)	Loss 0.85 (1.25)	Trans Loss 9.07 (8.74)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (84.8)
# Epoch: [79][ 500/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.21 (1.25)	Trans Loss 8.74 (8.75)	CST Loss 0.11 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (84.7)
# Epoch: [79][ 600/1000]	Time 1.3 (1.4)	Data 0.3 (0.4)	Loss 3.42 (1.25)	Trans Loss 8.74 (8.75)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 66.7 (84.8)
# Epoch: [79][ 700/1000]	Time 1.5 (1.4)	Data 0.4 (0.4)	Loss 1.34 (1.26)	Trans Loss 8.66 (8.74)	CST Loss 0.11 (0.10)	Fix Loss 0.14 (0.01)	Cls Acc 66.7 (84.3)
# Epoch: [79][ 800/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 2.18 (1.26)	Trans Loss 9.37 (8.73)	CST Loss 0.10 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 33.3 (84.4)
# Epoch: [79][ 900/1000]	Time 1.3 (1.4)	Data 0.4 (0.4)	Loss 1.12 (1.27)	Trans Loss 8.84 (8.73)	CST Loss 0.08 (0.10)	Fix Loss 0.00 (0.01)	Cls Acc 100.0 (84.1)
# Test: [  0/341]	Time  1.471 ( 1.471)	Loss 1.4318e-01 (1.4318e-01)	Acc@1 100.00 (100.00)	Acc@5 100.00 (100.00)
# Test: [100/341]	Time  0.096 ( 0.110)	Loss 1.2624e+00 (4.6037e-01)	Acc@1  33.33 ( 84.16)	Acc@5 100.00 (100.00)
# Test: [200/341]	Time  0.096 ( 0.103)	Loss 4.1318e-01 (4.4303e-01)	Acc@1 100.00 ( 85.07)	Acc@5 100.00 (100.00)
# Test: [300/341]	Time  0.096 ( 0.101)	Loss 3.0584e-01 (4.3273e-01)	Acc@1 100.00 ( 84.50)	Acc@5 100.00 (100.00)
#  * Acc@1 84.149 Acc@5 100.000
#
# Device-specific results:
# Device a: 84.15% (860/1022)
# Test: [  0/125]	Time  1.492 ( 1.492)	Loss 7.1559e-01 (7.1559e-01)	Acc@1 100.00 (100.00)	Acc@5 100.00 (100.00)
# Test: [100/125]	Time  0.096 ( 0.110)	Loss 1.1582e+00 (9.7763e-01)	Acc@1  33.33 ( 63.37)	Acc@5 100.00 ( 98.68)
#  * Acc@1 64.533 Acc@5 98.400
#
# Device-specific results:
# Device s3: 68.83% (53/77)
# Device c: 72.46% (50/69)
# Device s2: 70.00% (56/80)
# Device b: 62.50% (50/80)
# Device s1: 47.83% (33/69)
# Best Source Accuracy = 85.0
# Best Target Accuracy = 67.7
# Test: [  0/110]	Time  1.523 ( 1.523)	Loss 8.2090e-01 (8.2090e-01)	Acc@1  66.67 ( 66.67)	Acc@5 100.00 (100.00)
# Test: [100/110]	Time  0.096 ( 0.110)	Loss 1.2084e+00 (5.9721e-01)	Acc@1  66.67 ( 79.21)	Acc@5 100.00 (100.00)
#  * Acc@1 79.091 Acc@5 99.697
#
# Device-specific results:
# Device a: 79.09% (261/330)
# Test Source Accuracy = 79.1
# Test: [  0/880]	Time  1.510 ( 1.510)	Loss 8.0656e-01 (8.0656e-01)	Acc@1  66.67 ( 66.67)	Acc@5 100.00 (100.00)
# Test: [100/880]	Time  0.096 ( 0.110)	Loss 1.2134e+00 (1.1194e+00)	Acc@1  33.33 ( 58.75)	Acc@5 100.00 ( 98.35)
# Test: [200/880]	Time  0.096 ( 0.103)	Loss 3.5052e-01 (1.1284e+00)	Acc@1 100.00 ( 57.88)	Acc@5 100.00 ( 98.34)
# Test: [300/880]	Time  0.096 ( 0.101)	Loss 3.4111e-01 (1.1493e+00)	Acc@1 100.00 ( 57.59)	Acc@5 100.00 ( 98.01)
# Test: [400/880]	Time  0.096 ( 0.100)	Loss 1.9261e+00 (1.1570e+00)	Acc@1   0.00 ( 57.11)	Acc@5 100.00 ( 98.17)
# Test: [500/880]	Time  0.096 ( 0.099)	Loss 2.1844e+00 (1.1444e+00)	Acc@1  33.33 ( 57.55)	Acc@5  66.67 ( 98.14)
# Test: [600/880]	Time  0.096 ( 0.099)	Loss 1.6527e+00 (1.1482e+00)	Acc@1  33.33 ( 57.57)	Acc@5 100.00 ( 98.00)
# Test: [700/880]	Time  0.097 ( 0.098)	Loss 1.9206e-01 (1.1403e+00)	Acc@1 100.00 ( 57.77)	Acc@5 100.00 ( 98.10)
# Test: [800/880]	Time  0.097 ( 0.098)	Loss 7.8782e-01 (1.1430e+00)	Acc@1  66.67 ( 57.22)	Acc@5 100.00 ( 98.34)
#  * Acc@1 57.468 Acc@5 98.294
#
# Device-specific results:
# Device b: 63.53% (209/329)
# Device s3: 58.79% (194/330)
# Device s1: 47.58% (157/330)
# Device s2: 50.30% (166/330)
# Device c: 73.25% (241/329)
# Device s4: 56.97% (188/330)
# Device s6: 53.03% (175/330)
# Device s5: 56.36% (186/330)
# Test Target Accuracy = 57.5
